# %%
from data_loader import dataloader
import matplotlib.pyplot as plt
user,ratings,movies = dataloader()
print(user.head())
print(movies.head())
print(ratings.head())
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
tags = [i.split("|") for i in movies["genres"].unique()]
columns = list(set([i for lst in tags for i in lst]))
print(columns)
for col in columns:
    movies[col] = movies["genres"].apply(lambda x: 1 if col in x else 0)
num_genres = []
for col in columns:
    for i in movies[col]:
        z = movies[col].sum()
    num_genres.append(z)
plt.bar(columns, num_genres)
plt.show()
# Out:
# ['Horror', 'Romance', 'Documentary', 'Mystery', 'Film-Noir', 'Comedy', 'Animation', 'Western', 'Adventure', 'Drama', "Children's", 'Thriller', 'Action', 'War', 'Sci-Fi', 'Crime', 'Musical', 'Fantasy']

# %%
rt = [1,2,3,4,5]
k = []
for j in rt:
    z= 0
    for i in ratings['rating']:
        if i==j : z+=1
    k.append(z)

plt.bar(rt, k)
plt.show()

# %%
import numpy as np
l = []
m = []
for i in ratings["movie_id"]:
    l.append(i)
for i in movies["movie_id"]:
    m.append(l.count(i))
    
print(m)

# %%
import numpy as np 
print(np.mean(m))
print(m.count(0))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ["not_rated","rated"]
k = m.__len__()-m.count(0)
pie = [m.count(0),k]
ax.pie(pie, labels = langs,autopct='%1.2f%%')
ax2 = fig.add_axes([0,1,1,1])
ax2.axis('equal')
langs2 = ('rated', 'sum')
pie2 = [np.sum(m),6040*3883-np.sum(m)]
ax2.pie(pie2, labels= langs2,autopct='%1.2f%%' )
plt.show()
# Out:
# 257.5866597991244
# 177

# %%
num_rating = []
us = []
for i in ratings["user_id"]:
    us.append(i)
for i in user["user_id"]:
    num_rating.append(us.count(i))
print(num_rating)

# %%
print(num_rating.count(0))
# Out:
# 0
